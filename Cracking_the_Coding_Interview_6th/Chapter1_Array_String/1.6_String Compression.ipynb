# %% [markdown]
# #String Compression: Implement a method to perform basic string compression using the counts
# of repeated characters. For example, the string aabcccccaaa would become a2b1c5a3. If the
# "compressed" string would not become smaller than the original string, your method should return
# the original string. You can assume the string has only uppercase and lowercase letters (a - z).

# %%
import time

tick = time.time()
inputStr = "...;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaa"
outputStr = ""
# Storing 1st character
previousCh = inputStr[0]
count = 1
outputStr = ""+previousCh
# Loop from the 2nd character
for i in range(1,len(inputStr)):
    # Check if previousCh and current input same or not
    if(inputStr[i]==previousCh):
        count+=1
        continue
    else:
        outputStr+=str(count)
        previousCh=inputStr[i]
        outputStr+=previousCh
        count=1
outputStr+=str(count)
#print(outputStr)
tock = time.time()
print("Execution time :", tock-tick)
# Out:
# Execution time : 0.027389049530029297

# %%
# The above code use string concatenation (ch+=ch2) where runtime is (0+1) + (1+1) +...+ m = m(m+1)/2 = O(m^2)

# %%
import time

tick = time.time()
inputStr = "...;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaalllllllllllllcccccccnnnnnnnmmmmmmmrrrr333335555555kdsaflsdsdfladflkajshdflashdlfasdlaaaaaabbbbbbbbbbbccadnf;affffffffffkkkkkkkkkkkeeeeeeerrrrrrwwwwwwwwwvvvvvvsssssddddddvvvvvvaoisf;awoelnflasdknfadedeeeevvvvasdsdskkkkk;;;;;ssseeennnnnggggsdcccccccaaa"

outputList = []
# Storing 1st character
previousCh = inputStr[0]
count = 1
outputList.append(previousCh)
# Loop from the 2nd character
for i in range(1,len(inputStr)):
    # Check if previousCh and current input same or not
    if(inputStr[i]==previousCh):
        count+=1
        continue
    else:
        outputList.append(str(count))
        previousCh=inputStr[i]
        outputList.append(previousCh)
        count=1
outputList.append(str(count))
outputStr = ''.join(outputList)
#print(outputStr)
tock = time.time()
print("Execution time :", tock-tick)
# Out:
# Execution time : 0.025684118270874023
